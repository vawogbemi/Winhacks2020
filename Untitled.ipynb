# %% [markdown]
# # WinHacks2020
#
# This is my submission for winhacks 2020, I did the Windsor City Data Challenge which involves looking at the cities data set for traffic in 3 intersections, finding insights and proposing solutions to their traffic problem.

# %%
#import statements

import numpy
import matplotlib as plt
import pandas as pd

# %% [markdown]
# ## Getting Started
#
# For this challenge we were provided with 3 datasets(Dorchester Road and Huron Church Road.csv, Malden Road and Huron Church Road.csv, Totten Street and Huron Church Road.csv); each one corresponding to a busy intersection in Windsor. The datasets have columns which represent start time and turns (right, left, thru, u-turn, peds_cw, peds_ccw) for each cardinal direction (north, east, south, west), in total there are 25 columns. Each row represents 15 min of time and each column records the number of occurances within 15 mins intervals.Lastly there are multiple tables in each dataset there is a main one which totals occurances for every vehicle and several seperate tables for individual vehicles, each table is 5760 rows long.

# %%
Ddata = pd.read_csv('cityofwindsordata/count/Dorchester Road and Huron Church Road.csv')
Ddata.head()
# Out:
#       Start Time SBRight SBThru SBLeft SBU-Turn SBPeds CW SBPeds CCW WBRight  \
# 0  1/1/2020 0:00       1     18      0        0         0          0       0
# 1  1/1/2020 0:15       6     27      0        0         0          0       0
# 2  1/1/2020 0:30       4     37      0        0         0          0       2
# 3  1/1/2020 0:45       6     28      0        0         0          0       1
# 4  1/1/2020 1:00       8     41      0        0         0          0       1
#
#   WBThru WBLeft  ... NBLeft NBU-Turn NBPeds CW NBPeds CCW EBRight EBThru  \
# 0      0      1  ...      0        0         0          0      10      0
# 1      0      1  ...      0        0         0          0      10      0
# 2      0      3  ...      2        0         0          0       5      0
# 3      1      2  ...      3        0         0          0       7      0
# 4      0      0  ...      0        0         0          0       9      0
#
#   EBLeft EBU-Turn EBPeds CW EBPeds CCW
# ...

# %% [markdown]
# ## Datasets
# ### Dorchester Road and Huron Church Road

# %%
#d = (60 * 24 * 60 )/15 
Ddata = pd.read_csv('cityofwindsordata/count/Dorchester Road and Huron Church Road.csv', nrows= 5760)

#Single-Unit Trucks
DdataSVT = pd.read_csv('cityofwindsordata/count/Dorchester Road and Huron Church Road.csv', skiprows = 5764 ,nrows= 5760)

#Articulated Trucks
DdataAT = pd.read_csv('cityofwindsordata/count/Dorchester Road and Huron Church Road.csv', skiprows = 11528 ,nrows= 5760)

#Buses
DdataB = pd.read_csv('cityofwindsordata/count/Dorchester Road and Huron Church Road.csv', skiprows = 17292  ,nrows= 5760)

#Work Vans
DdataWV = pd.read_csv('cityofwindsordata/count/Dorchester Road and Huron Church Road.csv', skiprows = 23056 ,nrows= 5760)

#Bicycles
DdataBy = pd.read_csv('cityofwindsordata/count/Dorchester Road and Huron Church Road.csv', skiprows = 28820 ,nrows= 5760)

#Pedestrians
DdataP = pd.read_csv('cityofwindsordata/count/Dorchester Road and Huron Church Road.csv', skiprows = 34585 ,nrows= 5760)

#cleaning up column name - replace spaces with _ and lowcase 
Dset = [Ddata, DdataSVT, DdataAT, DdataB, DdataWV, DdataBy, DdataP]
for i in Dset:
    i.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %% [markdown]
# ### Malden Road and Huron Church Road

# %%
Mdata = pd.read_csv('cityofwindsordata/count/Malden Road and Huron Church Road.csv', nrows= 5760)

#Single-Unit Trucks
MdataSVT = pd.read_csv('cityofwindsordata/count/Malden Road and Huron Church Road.csv', skiprows = 5764 ,nrows= 5760)

#Articulated Trucks
MdataAT = pd.read_csv('cityofwindsordata/count/Malden Road and Huron Church Road.csv', skiprows = 11528 ,nrows= 5760)

#Buses
MdataB = pd.read_csv('cityofwindsordata/count/Malden Road and Huron Church Road.csv', skiprows = 17292  ,nrows= 5760)

#Work Vans
MdataWV = pd.read_csv('cityofwindsordata/count/Malden Road and Huron Church Road.csv', skiprows = 23056 ,nrows= 5760)

#Bicycles
MdataBy = pd.read_csv('cityofwindsordata/count/Malden Road and Huron Church Road.csv', skiprows = 28820 ,nrows= 5760)

#Pedestrians
MdataP = pd.read_csv('cityofwindsordata/count/Malden Road and Huron Church Road.csv', skiprows = 34585 ,nrows= 5760)

#cleaning up column name - replace spaces with _ and lowcase 
Mset = [Mdata, MdataSVT, MdataAT, MdataB, MdataWV, MdataBy, MdataP]
for i in Mset:
    i.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %% [markdown]
# ### Totten Street and Huron Church Road

# %%
Tdata = pd.read_csv('cityofwindsordata/count/Totten Street and Huron Church Road.csv', nrows= 5760)

#Single-Unit Trucks
TdataSVT = pd.read_csv('cityofwindsordata/count/Totten Street and Huron Church Road.csv', skiprows = 5764 ,nrows= 5760)

#Articulated Trucks
TdataAT = pd.read_csv('cityofwindsordata/count/Totten Street and Huron Church Road.csv', skiprows = 11528 ,nrows= 5760)

#Buses
TdataB = pd.read_csv('cityofwindsordata/count/Totten Street and Huron Church Road.csv', skiprows = 17292  ,nrows= 5760)

#Work Vans
TdataWV = pd.read_csv('cityofwindsordata/count/Totten Street and Huron Church Road.csv', skiprows = 23056 ,nrows= 5760)

#Bicycles
TdataBy = pd.read_csv('cityofwindsordata/count/Totten Street and Huron Church Road.csv', skiprows = 28820 ,nrows= 5760)

#Pedestrians
TdataP = pd.read_csv('cityofwindsordata/count/Totten Street and Huron Church Road.csv', skiprows = 34585 ,nrows= 5760)

#cleaning up column name - replace spaces with _ and lowcase 
Tset = [Tdata, TdataSVT, TdataAT, TdataB, TdataWV, TdataBy, TdataP]
for i in Tset:
    i.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %% [markdown]
# # Plotting the data
#
# Lets plot some data! We'll start with Dorchester Road and Huron Church Road first and try to get some insights.

# %%
#plots all available values
Ddata.plot(x = 'start_time',figsize = (35, 10))

#plot 1 or more values
Ddata.plot(x = 'start_time', y = ['sbthru'], figsize = (35, 10))
Ddata.plot(x = 'start_time', y = ['nbthru'], figsize = (35, 10))

#Excludes specific colums from data make it easier to read
exclude = ['nbthru', 'sbthru', 'sbright', 'wbthru', 'wbright', 'ebthru', 'ebright']
Ddata.drop(exclude, axis = 1).plot(x = 'start_time', figsize = (35, 10))

# %% [markdown]
# ## Observations
# Looking at the data from this I right away noticed the high amount of thru values compared to the other values (nbthru, sbthru) and since our goal is to look at the cause of backups we will mostly focus on the high values. It would also be nice to compare this with data from other intersections so I will plot them too

# %% [markdown]
# ### Malden Road and Huron Church Road

# %%
# plots all available values
Mdata.plot(x = 'start_time',figsize = (35, 10))

#plot 1 or more values
Mdata.plot(x = 'start_time', y = ['sbthru'], figsize = (35, 10))
Mdata.plot(x = 'start_time', y = ['nbthru'], figsize = (35, 10))

#Excludes specific colums from data make it easier to read
exclude = ['nbthru', 'sbthru', 'sbright', 'wbthru', 'wbright', 'ebthru', 'ebright']
Mdata.drop(exclude, axis = 1).plot(x = 'start_time', figsize = (35, 10))

# %% [markdown]
# ### Totten Street and Huron Church Road

# %%
# plots all available values
Tdata.plot(x = 'start_time',figsize = (35, 10))

#plot 1 or more values
Tdata.plot(x = 'start_time', y = ['sbthru'], figsize = (35, 10))
Tdata.plot(x = 'start_time', y = ['nbthru'], figsize = (35, 10))

#Excludes specific colums from data make it easier to read
exclude = ['nbthru', 'sbthru', 'sbright', 'wbthru', 'wbright', 'ebthru', 'ebright']
Tdata.drop(exclude, axis = 1).plot(x = 'start_time', figsize = (35, 10))

# %% [markdown]
# seeing that all databases share the pattern we can now look at when the inersection recieve these huge spikes of vehicles

# %%
#Day
start = (1 * 24 * 60)/15
end
#probably use this
Ddata.loc[df['column_name'] == some_value]
# maybe
df.loc[df['column_name'].isin(some_values)]


# Set date as index
#EVEN BETTER 
#returns all columns between the 2 dates then you can just select thjem and plot them
specifictime = pd.date_range('2000-01-01', '2016-12-31')
all_stocks = pd.DataFrame(index = dates)
